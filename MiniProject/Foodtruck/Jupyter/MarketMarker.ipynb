# %%
import platform
import folium
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)

plt.rcParams["figure.figsize"] = [12,6]
# %matplotlib inline

# %%
mk = pd.read_csv('C://Users/user/Desktop/project/datasource/marketinfo/market1.csv', encoding='CP949')

# %%
mk.head()
# Out:
#      상가업소번호          상호명      지점명 상권업종대분류명  상권업종중분류명     상권업종소분류명     표준산업분류명  \
# 0  28523551  엘가커피부산아시아드점  부산아시아드점       음식    커피점/카페  커피전문점/카페/다방    비알콜 음료점업
# 1  28498271    비비안아울렛중계점   아울렛중계점       소매      의복의류     셔츠/내의/속옷         NaN
# 2  28512174  연세정신건강의학과의원      NaN       의료        병원         기타병원         NaN
# 3  28499926  독일지멘스보청기은평점      은평점       소매  의약/의료품소매        보청기판매  의료용 기구 소매업
# 4  28490321         서울모드      NaN       음식    커피점/카페  커피전문점/카페/다방    비알콜 음료점업
#
#      시도명  시군구코드 시군구명    ...                          건물관리번호              건물명  \
# 0  부산광역시  26470  연제구    ...      2647010100111980000000000   부산아시아드주경기장노외주차장
# 1  서울특별시  11350  노원구    ...      1135010600105090000000000           2001아울렛
# 2  서울특별시  11110  종로구    ...      1111017400102990000000000             유림문화사
# 3  서울특별시  11380  은평구    ...      1138010300102810000000000               NaN
# 4  서울특별시  11680  강남구    ...      1168010700105170000000000              SM빌딩
#
# ...

# %%
mkloc = mk[["시도명","시군구명","상권업종대분류명","상호명","위도","경도"]]

# %%
mkloc.head()
# Out:
#      시도명 시군구명 상권업종대분류명          상호명         위도          경도
# 0  부산광역시  연제구       음식  엘가커피부산아시아드점  35.191284  129.062033
# 1  서울특별시  노원구       소매    비비안아울렛중계점  37.641280  127.067888
# 2  서울특별시  종로구       의료  연세정신건강의학과의원  37.573196  127.014500
# 3  서울특별시  은평구       소매  독일지멘스보청기은평점  37.610888  126.929871
# 4  서울특별시  강남구       음식         서울모드  37.519315  127.022211

# %%
mkloc = mkloc.set_index("시도명")

# %%
mkloc = mkloc.loc["서울특별시"][["시군구명","상권업종대분류명","상호명","위도","경도"]]

# %%
mkloc.head()
# Out:
#       시군구명 상권업종대분류명          상호명         위도          경도
# 시도명
# 서울특별시  노원구       소매    비비안아울렛중계점  37.641280  127.067888
# 서울특별시  종로구       의료  연세정신건강의학과의원  37.573196  127.014500
# 서울특별시  은평구       소매  독일지멘스보청기은평점  37.610888  126.929871
# 서울특별시  강남구       음식         서울모드  37.519315  127.022211
# 서울특별시  성북구       음식    국대떡볶이길음역점  37.603455  127.024543

# %%
mkloc = mkloc.set_index("시군구명")

# %%
mkloc = mkloc.loc["노원구"][["상권업종대분류명","상호명","위도","경도"]]

# %%
mkloc = mkloc.set_index("상권업종대분류명")

# %%
mkloc = mkloc.loc["음식"][["상호명","위도","경도"]]

# %%
mkloc = mkloc.reset_index()

# %%
mkloc.head()
# Out:
#   상권업종대분류명              상호명         위도          경도
# 0       음식             청암회관  37.648247  127.078464
# 1       음식  서울과학기술대학교제2학생식당  37.633069  127.076771
# 2       음식             브레드원  37.652170  127.060646
# 3       음식         오복희숯불생고기  37.663752  127.073660
# 4       음식             아자카야  37.660462  127.074585

# %%
len(mkloc)
# Out:
# 3766

# %%
locations = mkloc[['위도','경도']]
locationlist = locations.values.tolist()
len(locationlist)
locationlist[7]
# Out:
# [37.62134059, 127.0725436]

# %%
from tqdm import tqdm_notebook

# %%
map = folium.Map(location=[37.651879, 127.071990], zoom_start=13)
for num in tqdm_notebook(range(0,100)):    
    #print(df.loc[num]["위치정보(X)"] )
    folium.CircleMarker([mkloc["위도"][num], mkloc["경도"][num]], radius=1).add_to(map)
map
# Out:
# ...
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map = folium.Map(location=[37.651879, 127.071990], zoom_start=13)

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
folium.CircleMarker([mkloc["위도"][0], mkloc["경도"][0]], radius=2).add_to(map)

# %%
for num in tqdm_notebook(range(0,2000)):    
    #print(df.loc[num]["위치정보(X)"] )
    folium.CircleMarker([mkloc["위도"][num], mkloc["경도"][num]], radius=1).add_to(map)
map
# Out:
# ...
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
