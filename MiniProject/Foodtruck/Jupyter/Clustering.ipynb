# %%
import folium
import pandas as pd

# %%
from folium.plugins import MarkerCluster
from folium.plugins import HeatMap

# %%
mk = pd.read_csv('C://Users/user/Desktop/project/datasource/marketinfo/market1.csv', encoding='CP949')

# %%
gu_name = "서대문구"

# %%
mkloc = mk[["시도명","시군구명","상권업종대분류명","상호명","위도","경도"]]

# %%
mkloc = mkloc.set_index("시군구명")

# %%
mkloc = mkloc.loc[gu_name][["상권업종대분류명","상호명","위도","경도"]]

# %%
mkloc = mkloc.set_index("상권업종대분류명")

# %%
mkloc = mkloc.loc["음식"][["상호명","위도","경도"]]

# %%
mkloc = mkloc.reset_index()
mkloc.head()
# Out:
#   상권업종대분류명            상호명         위도          경도
# 0       음식           에브리돈  37.579029  126.910288
# 1       음식         버거킹연희점  37.566797  126.930502
# 2       음식  CARIBOUCOFFEE  37.558864  126.946054
# 3       음식    이화여자대학교진관식당  37.564281  126.950301
# 4       음식          시네마치킨  37.576644  126.931346

# %%
mkloc_sp = mkloc.sample(n=500)

# %%
map = folium.Map(location=[mkloc_sp['위도'].mean(), 
                                mkloc_sp['경도'].mean()], 
                      zoom_start=13)

# %%
mc = MarkerCluster()

# %%
for row in mkloc.itertuples():
    mc.add_child(folium.Marker(location=[row.위도,row.경도]))

# %%
map.add_child(mc)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
heat_data = [[row['위도'],row['경도']] for index, row in mkloc_sp.iterrows()]

# %%
map2 = folium.Map(location = NOWON, zoom_start = 17)
HeatMap(heat_data, max_zoom = 1000, blur = 10, radius = 30).add_to(map2)

# %%
map2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
